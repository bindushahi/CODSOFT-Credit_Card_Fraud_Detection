# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
pip install warnings
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement warnings (from versions: none)
# ERROR: No matching distribution found for warnings

# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown

# %%
# Google Drive file ID
file_id = "1gdZH-gWNM8SgViSUGC0KKP1MuqLPBpfJ"
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# %%
# Download the file
output_file = "creditcard_2023.csv"
gdown.download(download_url, output_file, quiet=False)
print("Dataset downloaded successfully!")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1gdZH-gWNM8SgViSUGC0KKP1MuqLPBpfJ
# From (redirected): https://drive.google.com/uc?export=download&id=1gdZH-gWNM8SgViSUGC0KKP1MuqLPBpfJ&confirm=t&uuid=e5b0a8f5-a0a5-477c-9bf8-c4822fc2c240
# To: c:\Users\user\Desktop\CODSOFT-Credit_Card_Fraud_Detection\creditcard_2023.csv
# 100%|██████████| 325M/325M [00:29<00:00, 11.0MB/s]
# Dataset downloaded successfully!

# %%
#loading the dataset to the pandas dataframe
credit_card = pd.read_csv('creditcard_2023.csv', delimiter=',')

# %%
credit_card.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
credit_card.tail()
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 568625 -0.370393  0.189694 -0.938153  ...  0.167503  0.419731  1.288249
# 568626 -0.016935 -0.147733  0.483894  ...  0.031874  0.388161 -0.154257
# 568627 -0.070958 -0.019997 -0.122048  ...  0.140788  0.536523 -0.211100
# 568628  0.580568 -0.207723  0.893527  ... -0.060381 -0.195609 -0.175488
# 568629 -0.347613 -0.340814  0.253971  ...  0.534853 -0.291514  0.157303
#
#              V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
# anyone else clones your repo, they can use the script to automatically download the dataset from Google Drive:


# # import gdown
# # import os

# # # Google Drive file ID
# # file_id = "1gdZH-gWNM8SgViSUGC0KKP1MuqLPBpfJ"
# # download_url = f"https://drive.google.com/uc?export=download&id={file_id}"
# # output_file = "creditcard_2023.csv"

# # # Download the file only if it doesn't exist
# # if not os.path.exists(output_file):
# #     print("Downloading dataset from Google Drive...")
# #     gdown.download(download_url, output_file, quiet=False)
# #     print("Dataset downloaded successfully!")
# # else:
# #     print("Dataset already exists. Skipping download.")

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
credit_card.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#to check the number of 0 and 1 which is genuine and fraud transcation number
credit_card['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
#dataset are highly unbalanced
#-> 0 normal transaction and 1 is for fraudelent transaction
# seperating the data for analysis
legit=credit_card[credit_card.Class==0]
fraud=credit_card[credit_card.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (284315, 31)

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean      12026.313506
# std        6929.500715
# min          50.120000
# 25%        6034.540000
# 50%       11996.900000
# 75%       18040.265000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count    284315.000000
# mean      12057.601763
# std        6909.750891
# min          50.010000
# 25%        6074.640000
# 50%       12062.450000
# 75%       18033.780000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
credit_card.groupby('Class').mean()
# Out:
#                   id        V1        V2        V3        V4        V5  \
# Class
# 0      142442.987714  0.505761 -0.491878  0.682095 -0.735981  0.338639
# 1      426186.012286 -0.505761  0.491878 -0.682095  0.735981 -0.338639
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.435088  0.491234 -0.144294  0.585522  ... -0.179851 -0.10964
# 1     -0.435088 -0.491234  0.144294 -0.585522  ...  0.179851  0.10964
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.014098 -0.010255  0.130107 -0.061847 -0.071052 -0.214002 -0.102024
# 1      0.014098  0.010255 -0.130107  0.061847  0.071052  0.214002  0.102024
#
#              Amount
# Class
# 0      12026.313506
# 1      12057.601763
#
# [2 rows x 30 columns]

# %%
#to check if the dataset is balanced or not
print(credit_card['Class'].value_counts(normalize=True) * 100)
# Out:
# Class
# 0    50.0
# 1    50.0
# Name: proportion, dtype: float64

# %%
credit_card['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
#splitting the data inot features and targets
X= credit_card.drop(columns='Class',axis=1) #that is column
Y= credit_card['Class']

# %%
print(X)
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %%
print(Y)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 568625    1
# 568626    1
# 568627    1
# 568628    1
# 568629    1
# Name: Class, Length: 568630, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (568630, 30) (398041, 30) (170589, 30)

# %%
import pickle

# %%
#Before Normalization (Original Amount values) preprocessing

print("Mean:", credit_card['Amount'].mean())
print("Standard Deviation:", credit_card['Amount'].std())
print(credit_card[['Amount']].head())
# Out:
# Mean: 12041.957634577848
# Standard Deviation: 6919.6444494291845
#      Amount
# 0  17982.10
# 1   6531.37
# 2   2513.54
# 3   5384.44
# 4  14278.97

# %%
#Applying Normalization 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
credit_card['Amount'] = scaler.fit_transform(credit_card[['Amount']])

# %%
#After Normalization
 
print("Mean:", credit_card['Amount'].mean())
print("Standard Deviation:", credit_card['Amount'].std())
print(credit_card[['Amount']].head())
# Out:
# Mean: -4.02123978325023e-16
# Standard Deviation: 1.000000879307563
#      Amount
# 0  0.858447
# 1 -0.796369
# 2 -1.377011
# 3 -0.962119
# 4  0.323285

# %%
#Model training i.e logistic regression
model=LogisticRegression()

# %%
#training the logistic regression model with training data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#accuracy on testing data
print("LogisticRegression Accuracy:",model.score(X_test,Y_test)*100)
# Out:
# LogisticRegression Accuracy: 99.51696768255867

# %%
#accuracy on training data
print("LogisticRegression Accuracy:",model.score(X_train,Y_train)*100)
# Out:
# LogisticRegression Accuracy: 99.53145530234323

# %%
#training the model other than logistic regression which is random forest which is more powerful model for fraud detection
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier(n_estimators=100,random_state=42) #initialize the model
rf_model.fit(X_train,Y_train)   #train the model
# Out:
# RandomForestClassifier(random_state=42)

# %%
#make the predictions
rf_pred=rf_model.predict(X_test)

# %%
#checking accuracy after using random forest model
accuracy = accuracy_score(Y_test, rf_pred)
print("Accuracy:", accuracy * 100, "%")
# Out:
# Accuracy: 99.98300007620655 %

# %%
# Evaluate the model Precision, Recall, and F1-Score For imbalanced datasets, precision, recall, and F1-score are better metrics than accuracy alone.
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# Precision: Proportion of true positive predictions over all positive predictions.
precision = precision_score(Y_test, rf_pred)
print("Precision:", precision)
# Out:
# Precision: 0.9999182137891551

# %%
# Recall: Proportion of true positive predictions over all actual positive cases.
recall = recall_score(Y_test, rf_pred)
print("Recall:", recall)
# Out:
# Recall: 0.999743002663427

# %%
# F1-Score: Harmonic mean of precision and recall.
f1 = f1_score(Y_test, rf_pred)
print("F1 Score:", f1)
# Out:
# F1 Score: 0.9998306005502562

# %%
 #visualize using the Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Generate confusion matrix
cm = confusion_matrix(Y_test, rf_pred)

# %%
# Create a heatmap to visualize the confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Legitimate', 'Fraudulent'], yticklabels=['Legitimate', 'Fraudulent'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
 #visualize using the Precision-Recall Curve You want to evaluate how well your model is detecting the minority class (fraudulent transactions), which is the key objective for your project.
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

# %%
# Get precision and recall values
precision, recall, _ = precision_recall_curve(Y_test, model.predict_proba(X_test)[:, 1])

# %%
# Calculate the AUC (Area Under the Curve)
pr_auc = auc(recall, precision)

# %%
# Plot the precision-recall curve
plt.figure(figsize=(6, 5))
plt.plot(recall, precision, color='b', label=f'Precision-Recall Curve (AUC = {pr_auc:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.show()
